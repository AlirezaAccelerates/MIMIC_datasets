# %% [markdown]
# This notebook explores the MIMIC III dataset using BigQuery and Google Cloud. First, you need to gain access to the dataset through this [link](https://physionet.org/content/mimiciii/1.4/) by meeting their requirements. Then, go to [Google Cloud BigQuery](https://cloud.google.com/bigquery), navigate to your BigQuery Studio, and create a new folder called "physionet-data." Next, return to the MIMIC III webpage, scroll down, and click on "Request access using Google BigQuery." This will automatically add the dataset to your Google account in the "physionet-data" folder. Now, you are ready to follow along with this notebook.

# %% [markdown]
# ## Install necessary libraries.
# tableone is a tool for producing summary statistics

# %%
# %pip install tableone
# Out:
# Requirement already satisfied: tableone in /usr/local/lib/python3.10/dist-packages (0.9.1)
# Requirement already satisfied: jinja2>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from tableone) (3.1.4)
# Requirement already satisfied: numpy>=1.19.1 in /usr/local/lib/python3.10/dist-packages (from tableone) (1.25.2)
# Requirement already satisfied: openpyxl>=3.1.2 in /usr/local/lib/python3.10/dist-packages (from tableone) (3.1.3)
# Requirement already satisfied: pandas>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from tableone) (2.0.3)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.10/dist-packages (from tableone) (1.11.4)
# Requirement already satisfied: statsmodels>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from tableone) (0.14.2)
# Requirement already satisfied: tabulate>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tableone) (0.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=3.1.4->tableone) (2.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl>=3.1.2->tableone) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->tableone) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->tableone) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0.3->tableone) (2024.1)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.14.1->tableone) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.14.1->tableone) (24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.14.1->tableone) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import tableone

from google.colab import files
from google.colab import auth
auth.authenticate_user()
print('Authenticated')

# %load_ext google.colab.data_table
# Out:
# Authenticated

# %%
# change the PROJECT_ID to yours
# %env GOOGLE_CLOUD_PROJECT = PROJECT_ID
# Out:
# env: GOOGLE_CLOUD_PROJECT=sccm-test-426219

# %% [markdown]
# ## Exploring the dataset

# %%
# %%bigquery --project PROJECT_ID
#
#   SELECT
#       le.SUBJECT_ID,
#       le.CHARTTIME,
#       le.VALUENUM,
#       dle.LABEL,
#   FROM
#       `physionet-data.mimiciii_clinical.labevents` le
#   LEFT JOIN (
#       SELECT
#           ITEMID,
#           LABEL
#       FROM
#           `physionet-data.mimiciii_clinical.d_labitems`
#       LIMIT 100
#   ) dle
#       ON dle.ITEMID = le.ITEMID
#   WHERE
#       le.ITEMID IN (
#           SELECT
#               ITEMID
#           FROM
#               `physionet-data.mimiciii_clinical.d_labitems` dle
#           WHERE
#               CATEGORY IN ("Blood Gas", "BLOOD GAS")
#           LIMIT 100
#       )
#   ORDER BY
#       le.SUBJECT_ID ASC,
#       le.CHARTTIME ASC
#   LIMIT 100;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     SUBJECT_ID           CHARTTIME  VALUENUM                   LABEL
# 0            3 2101-10-12 09:18:00    106.00                 Glucose
# 1            3 2101-10-12 09:18:00     32.00  Hematocrit, Calculated
# 2            3 2101-10-12 09:18:00    244.00                     pO2
# 3            3 2101-10-12 09:18:00       NaN        Ventilation Rate
# 4            3 2101-10-12 09:18:00      1.15            Free Calcium
# ..         ...                 ...       ...                     ...
# 95           3 2101-10-12 18:17:00       NaN           SPECIMEN TYPE
# 96           3 2101-10-12 18:17:00     80.00                     pO2
# 97           3 2101-10-12 18:17:00     -1.00             Base Excess
# 98           3 2101-10-12 18:17:00      0.93            Free Calcium
# 99           3 2101-10-12 18:17:00     33.00                    pCO2
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Store data into a python variable

# %%
# %%bigquery df_example --project PROJECT_ID
#
#   SELECT
#       le.SUBJECT_ID,
#       le.HADM_ID,
#       le.CHARTTIME,
#       dle2.LABEL,
#       le.VALUENUM,
#   FROM
#       `physionet-data.mimiciii_clinical.labevents` le
#   LEFT JOIN (
#       SELECT
#           ITEMID,
#           LABEL
#       FROM
#           `physionet-data.mimiciii_clinical.d_labitems` dle2
#       LIMIT 100
#   ) dle2
#       ON dle2.ITEMID = le.ITEMID
#   WHERE
#       le.ITEMID IN (
#           SELECT
#               ITEMID
#           FROM
#               `physionet-data.mimiciii_clinical.d_labitems` dle2
#           WHERE
#               CATEGORY IN ("Blood Gas", "BLOOD GAS")
#           LIMIT 100
#       )
#   ORDER BY
#       le.SUBJECT_ID ASC,
#       le.CHARTTIME ASC
#   LIMIT 100;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
df_example.head(20)
# Out:
#     SUBJECT_ID  HADM_ID           CHARTTIME  \
# 0            3     <NA> 2101-10-12 09:18:00
# 1            3     <NA> 2101-10-12 09:18:00
# 2            3     <NA> 2101-10-12 09:18:00
# 3            3     <NA> 2101-10-12 09:18:00
# 4            3     <NA> 2101-10-12 09:18:00
# 5            3     <NA> 2101-10-12 09:18:00
# 6            3     <NA> 2101-10-12 09:18:00
# 7            3     <NA> 2101-10-12 09:18:00
# 8            3     <NA> 2101-10-12 09:18:00
# 9            3     <NA> 2101-10-12 09:18:00
# 10           3     <NA> 2101-10-12 09:18:00
# 11           3     <NA> 2101-10-12 09:18:00
# 12           3     <NA> 2101-10-12 09:18:00
# 13           3     <NA> 2101-10-12 09:18:00
# 14           3     <NA> 2101-10-12 09:18:00
# 15           3     <NA> 2101-10-12 09:18:00
# 16           3     <NA> 2101-10-12 09:18:00
# 17           3     <NA> 2101-10-12 09:18:00
# 18           3     <NA> 2101-10-12 09:18:00
# 19           3     <NA> 2101-10-12 09:18:00
#
#                                   LABEL  VALUENUM
# 0                               Glucose    106.00
# 1                  Calculated Total CO2     27.00
# 2                               Lactate      1.50
# 3   Calculated Bicarbonate, Whole Blood     25.00
# 4                             Intubated       NaN
# 5                Potassium, Whole Blood      3.80
# 6                           Base Excess      2.00
# 7                                   pO2    244.00
# 8                     Oxygen Saturation     98.00
# 9                          Tidal Volume    620.00
# 10                           Ventilator       NaN
# 11               Hematocrit, Calculated     32.00
# 12                Chloride, Whole Blood    105.00
# 13                         Free Calcium      1.15
# 14                        SPECIMEN TYPE       NaN
# 15                           Hemoglobin     10.50
# 16                                   pH      7.44
# 17                  Sodium, Whole Blood    139.00
# 18                                 pCO2     38.00
# 19                     Ventilation Rate       NaN

# %% [markdown]
# ## tabelone example

# %%
# %%bigquery demographics --project PROJECT_ID
#
#   SELECT *
#   FROM
#     `physionet-data.mimiciii_clinical.admissions` adm
#   LEFT JOIN
#     `physionet-data.mimiciii_clinical.patients` pat
#   on
#     adm.SUBJECT_ID = pat.SUBJECT_ID
#   LEFT JOIN
#     `physionet-data.mimiciii_clinical.icustays` iu
#   on
#     adm.SUBJECT_ID = iu.SUBJECT_ID
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
tableone.tableone(
    demographics,
    columns = [
        'GENDER',
        'LOS',
        'HOSPITAL_EXPIRE_FLAG',
        'ETHNICITY',
        ],
    categorical = [
        'ETHNICITY',
        'GENDER',
        ],
    groupby= 'HOSPITAL_EXPIRE_FLAG'
)
# Out:
#                                                                           Grouped by HOSPITAL_EXPIRE_FLAG
#                                                                                                   Missing       Overall             0            1
# n                                                                                                                116471        107122         9349
# GENDER, n (%)    F                                                                                         52801 (45.3)  48578 (45.3)  4223 (45.2)
#                  M                                                                                         63670 (54.7)  58544 (54.7)  5126 (54.8)
# LOS, mean (SD)                                                                                         57     4.6 (8.4)     4.5 (8.4)    5.8 (8.3)
# ETHNICITY, n (%) AMERICAN INDIAN/ALASKA NATIVE                                                                 70 (0.1)      65 (0.1)      5 (0.1)
#                  AMERICAN INDIAN/ALASKA NATIVE FEDERALLY RECOGNIZED TRIBE                                       5 (0.0)       3 (0.0)      2 (0.0)
#                  ASIAN                                                                                       2073 (1.8)    1906 (1.8)    167 (1.8)
#                  ASIAN - ASIAN INDIAN                                                                         336 (0.3)     329 (0.3)      7 (0.1)
#                  ASIAN - CAMBODIAN                                                                             48 (0.0)      36 (0.0)     12 (0.1)
#                  ASIAN - CHINESE                                                                              410 (0.4)     369 (0.3)     41 (0.4)
#                  ASIAN - FILIPINO                                                                              90 (0.1)      85 (0.1)      5 (0.1)
#                  ASIAN - JAPANESE                                                                               7 (0.0)       5 (0.0)      2 (0.0)
#                  ASIAN - KOREAN                                                                                14 (0.0)      13 (0.0)      1 (0.0)
#                  ASIAN - OTHER                                                                                 23 (0.0)      20 (0.0)      3 (0.0)
#                  ASIAN - THAI                                                                                   6 (0.0)       6 (0.0)
#                  ASIAN - VIETNAMESE                                                                            88 (0.1)      81 (0.1)      7 (0.1)
#                  BLACK/AFRICAN                                                                                112 (0.1)     109 (0.1)      3 (0.0)
#                  BLACK/AFRICAN AMERICAN                                                                    20308 (17.4)  19397 (18.1)    911 (9.7)
#                  BLACK/CAPE VERDEAN                                                                           323 (0.3)     300 (0.3)     23 (0.2)
#                  BLACK/HAITIAN                                                                                194 (0.2)     187 (0.2)      7 (0.1)
#                  CARIBBEAN ISLAND                                                                              12 (0.0)      12 (0.0)
#                  HISPANIC OR LATINO                                                                          3138 (2.7)    2958 (2.8)    180 (1.9)
#                  HISPANIC/LATINO - CENTRAL AMERICAN (OTHER)                                                    23 (0.0)      23 (0.0)
#                  HISPANIC/LATINO - COLOMBIAN                                                                   13 (0.0)      13 (0.0)
#                  HISPANIC/LATINO - CUBAN                                                                       54 (0.0)      54 (0.1)
#                  HISPANIC/LATINO - DOMINICAN                                                                  131 (0.1)     128 (0.1)      3 (0.0)
#                  HISPANIC/LATINO - GUATEMALAN                                                                 138 (0.1)     136 (0.1)      2 (0.0)
#                  HISPANIC/LATINO - HONDURAN                                                                     6 (0.0)       6 (0.0)
#                  HISPANIC/LATINO - MEXICAN                                                                     15 (0.0)      15 (0.0)
#                  HISPANIC/LATINO - PUERTO RICAN                                                               818 (0.7)     795 (0.7)     23 (0.2)
#                  HISPANIC/LATINO - SALVADORAN                                                                  32 (0.0)      32 (0.0)
#                  MIDDLE EASTERN                                                                               108 (0.1)     103 (0.1)      5 (0.1)
#                  MULTI RACE ETHNICITY                                                                         208 (0.2)     197 (0.2)     11 (0.1)
#                  NATIVE HAWAIIAN OR OTHER PACIFIC ISLANDER                                                     26 (0.0)      22 (0.0)      4 (0.0)
#                  OTHER                                                                                       2518 (2.2)    2330 (2.2)    188 (2.0)
#                  PATIENT DECLINED TO ANSWER                                                                   748 (0.6)     699 (0.7)     49 (0.5)
#                  PORTUGUESE                                                                                   226 (0.2)     204 (0.2)     22 (0.2)
#                  SOUTH AMERICAN                                                                                 9 (0.0)       9 (0.0)
#                  UNABLE TO OBTAIN                                                                             946 (0.8)     766 (0.7)    180 (1.9)
#                  UNKNOWN/NOT SPECIFIED                                                                       5686 (4.9)    4796 (4.5)    890 (9.5)
#                  WHITE                                                                                     76891 (66.0)  70348 (65.7)  6543 (70.0)
#                  WHITE - BRAZILIAN                                                                            115 (0.1)     112 (0.1)      3 (0.0)
#                  WHITE - EASTERN EUROPEAN                                                                      38 (0.0)      36 (0.0)      2 (0.0)
#                  WHITE - OTHER EUROPEAN                                                                       113 (0.1)     101 (0.1)     12 (0.1)
#                  WHITE - RUSSIAN                                                                              352 (0.3)     316 (0.3)     36 (0.4)

# %% [markdown]
# ## Exploring vital signs

# %%
# %%bigquery --project PROJECT_ID
#
#   SELECT
#     DISTINCT category,
#     label,
#     itemid
#   FROM
#     `physionet-data.mimiciii_clinical.d_items`
#   WHERE (
#       (linksto = 'chartevents')
#       and
#       category in ('Routine Vital Signs')
#       and
#       label in (
#           'Heart Rate', 'Temperature Celsius', 'O2 saturation pulseoxymetry',
#           'Arterial Blood Pressure diastolic', 'Arterial Blood Pressure mean', 'Arterial Blood Pressure systolic'
#           )
#       )
#   order by category ASC, label ASC
#   LIMIT 100
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#               category                              label  itemid
# 0  Routine Vital Signs  Arterial Blood Pressure diastolic  220051
# 1  Routine Vital Signs       Arterial Blood Pressure mean  220052
# 2  Routine Vital Signs   Arterial Blood Pressure systolic  220050
# 3  Routine Vital Signs                         Heart Rate  220045
# 4  Routine Vital Signs                Temperature Celsius  223762
